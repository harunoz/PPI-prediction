# %%
import numpy as np
import pandas as pd

# %%
data= pd.read_csv('mutations_encoded.tsv',sep="\t",encoding='utf-8', lineterminator='\n')

# %%
data.columns=['#Feature_AC' ,'Feature_short_label', 'Feature_range(s)',
 'Original_sequence' ,'Resulting_sequence' ,'Feature_type',
 'Feature_annotation' ,'Affected_protein_AC', 'Affected_protein_symbol',
 'Affected_protein_full_name' ,'Affected_protein_organism',
 'Interaction_participants', 'PubMedID', 'Figure_legend', 'Interaction_AC']

elaspicData= pd.read_csv('will_be_classified.csv')

homoSapiens=pd.DataFrame()

homoSapiens= data[data.Affected_protein_organism=='9606 - Homo sapiens'] #get homosapiens
homoSapiens= homoSapiens[homoSapiens.Feature_type !='mutation(MI:0118)']  #get correct mutations values refactor sometime!
homoSapiens= homoSapiens[homoSapiens.Feature_type != 'mutation with no effect(MI:2226)']

# %%
elaspicInteraction = pd.DataFrame()
elaspicInteraction = elaspicData[elaspicData.Type=='interface' ]

# %%
homoSapiens.head(5)
# Out:
#        #Feature_AC Feature_short_label Feature_range(s) Original_sequence  \
# 4355  EBI-12523581               V420A          420-420                 V
# 4356  EBI-12691313               F289L          289-289                 F
# 4357  EBI-12523583               Q418K          418-418                 Q
# 4358  EBI-12693334               E435K          435-435                 E
# 4359  EBI-12692465               R148W          148-148                 R
#
#      Resulting_sequence               Feature_type  \
# 4355                  A  mutation causing(MI:2227)
# 4356                  L  mutation causing(MI:2227)
# 4357                  K  mutation causing(MI:2227)
# 4358                  K  mutation causing(MI:2227)
# 4359                  W  mutation causing(MI:2227)
#
#                                      Feature_annotation  Affected_protein_AC  \
# 4355                                                NaN       uniPtkb:Q9P2R3
# 4356  MI:0612 (comment): Allele_ID: 2100_2792,- (rem...     uniPtkb:Q92731-3
# 4357                                                NaN       uniPtkb:Q9P2R3
# 4358  MI:0612 (comment): Allele_ID: 1959_17709,- (re...  intact:EBI-12690028
# 4359  MI:0612 (comment): Allele_ID: 51114_6216,- (re...       uniPtkb:Q9Y397
#
#      Affected_protein_symbol  Affected_protein_full_name  \
# 4355                  ANKFY1                         NaN
# 4356                    ESR2                         NaN
# 4357                  ANKFY1                         NaN
# 4358                    egr2                         NaN
# 4359                  ZDHHC9                         NaN
#
#      Affected_protein_organism  \
# 4355       9606 - Homo sapiens
# 4356       9606 - Homo sapiens
# 4357       9606 - Homo sapiens
# 4358       9606 - Homo sapiens
# 4359       9606 - Homo sapiens
#
#                                Interaction_participants  PubMedID  \
# 4355  uniPtkb:Q9P2R3(Ptein(MI:0326), 9606 - Homo sap...  27189942
# 4356  intact:EBI-12691290(ds dna(MI:0681), 9606 - Ho...  25910212
# 4357  uniPtkb:Q9P2R3(Ptein(MI:0326), 9606 - Homo sap...  27189942
# 4358  intact:EBI-12693327(ds dna(MI:0681), 9606 - Ho...  25910212
# 4359  intact:EBI-12692329(ds dna(MI:0681), 9606 - Ho...  25910212
#
#       Figure_legend Interaction_AC
# 4355  8 B and C, 9A   EBI-12509450
# 4356      Table S6B   EBI-12691308
# 4357  8 B and C, 9A   EBI-12509450
# 4358      Table S6B   EBI-12693329
# 4359      Table S6B   EBI-12692460

# %%
elaspicData.head(5)
# Out:
#    Unnamed: 0 Input_identifier UniProt_ID Mutation Status       Type  \
# 0           0           O14893     O14893     Y52D   done       core
# 1           1           O14893     O14893     Y52D   done  interface
# 2           2           O14893     O14893     Y52D   done  interface
# 3           3           P08709     P08709    R139Q   done       core
# 4           4           P08709     P08709    R139Q   done  interface
#
#   COSMIC_mut_ID ClinVar_mut_ID UniProt_mut_ID Domain_name  \
# 0             -              -              -        SIP1
# 1             -              -              -        SIP1
# 2             -              -              -        SIP1
# 3             -              -     VAR_006498         EGF
# 4             -              -     VAR_006498         EGF
#
#                ...               number_of_residues_mut  \
# 0              ...                                  248
# 1              ...                                  338
# 2              ...                                  324
# 3              ...                                   52
# 4              ...                                  283
#
#   IntraclashesEnergy1_wt IntraclashesEnergy1_mut IntraclashesEnergy2_wt  \
# 0                      -                       -                      -
# 1                51.9403                 51.8577                164.073
# 2                53.3621                 53.2632                36.9299
# 3                      -                       -                      -
# 4                26.9873                 26.7578                138.692
#
#   IntraclashesEnergy2_mut Interface_hydrophobic_area  \
# 0                       -                          -
# 1                 164.073                    435.525
# 2                 36.9299                    469.205
# 3                       -                          -
# 4                 138.692                    346.735
#
#   Interface_hydrophilic_area Interface_total_area  \
# 0                          -                    -
# 1                     236.44              671.965
# 2                    230.435               699.64
# 3                          -                    -
# 4                    246.295               593.03
#
#   Interface_contact_distance_wt Interface_contact_distance_mut
# 0                             -                              -
# 1                       2.64499                        2.64499
# 2                       3.85512                        3.36921
# 3                             -                              -
# 4                       3.27446                        3.27446
#
# [5 rows x 101 columns]

# %%
compare= pd.read_csv('compare.csv')

# %%
compare.head(5)
# Out:
#    Unnamed: 0 UniProt_ID Mutation
# 0           0     O14893     Y52D
# 1           1     O14893     Y52D
# 2           2     P08709    R139Q
# 3           3     P08709    R139Q
# 4           4     P08709    R139Q

# %%
for i in range(len(data)):
        for k in range(len(delete)):
            if(delete.iloc[k,1]==data.iloc[i,1] and delete.iloc[k,2]==data.iloc[i,2]):
                data.iloc[i,1]='NON'
