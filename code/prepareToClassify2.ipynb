# %%
import pandas as pd
import numpy as np
data=pd.read_csv('finalLLLL.csv')

# %%
#data.head(100)

# %%
dataD= pd.DataFrame()
dataD = data.loc[(data['feature_type'] =='mutation disrupting rate(MI:1129)') | 
                 (data['feature_type'] =='mutation increasing(MI:0382)') |
              ( data['feature_type'] =="mutation increasing rate(MI:1131)") |
                 (data['feature_type'] =="mutation with no effect(MI:2226)") |
                (data['feature_type']=="mutation disrupting strength(MI:1128)")|
               (data['feature_type']=="mutation disrupting(MI:0573)")|
               (data['feature_type']=="mutation increasing strength(MI:1132)")]

# %%
for i in range(len(dataD)):mutation disrupting rate(MI:1129)
    if(dataD.iloc[i,1]=='mutation disrupting rate(MI:1129)' or dataD.iloc[i,1]=='mutation disrupting strength(MI:1128)'
      or dataD.iloc[i,1]=='mutation disrupting rate(MI:1129)'):
        dataD.iloc[i,1]=0
    if(dataD.iloc[i,1]=='mutation increasing rate(MI:1131)' or 
       dataD.iloc[i,1]=='mutation increasing strength(MI:1132)' or 'mutation increasing(MI:0382)'
       or dataD.iloc[i,1]=='mutation with no effect(MI:2226)':
        dataD.iloc[i,1]=1
dataD.to_csv('deneme123.csv')
# Out:
#   File "<ipython-input-5-55b281e65603>", line 1
#     for i in range(len(dataD)):mutation disrupting rate(MI:1129)
#                                                  ^
# SyntaxError: invalid syntax

# %%
dataD = dataD.select_dtypes(include=np.number)
x = dataD[dataD.columns[np.concatenate([range(0,38),range(39,79)])]]
y = dataD.iloc[:,1:2:]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-61-20d0eed6cdc5> in <module>
#       1 dataD = dataD.select_dtypes(include=np.number)
# ----> 2 x = dataD[dataD.columns[np.concatenate([range(0,38),range(39,79)])]]
#       3 y = dataD.iloc[:,1:2:]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    2093
#    2094         key = com._values_from_object(key)
# -> 2095         result = getitem(key)
#    2096         if not is_scalar(result):
#    2097             return promote(result)
#
# IndexError: index 2 is out of bounds for axis 1 with size 2

# %%
dataD
# Out:
#       Unnamed: 0  feature_type
# 15            19             0
# 16            20             0
# 17            21             0
# 18            22             0
# 19            23             0
# 37            49             0
# 38            50             0
# 68            88             0
# 69            90             0
# 70            92             0
# 71            93             0
# 72            94             0
# 73            95             0
# 116          145             0
# 125          158             0
# 126          160             0
# 127          161             0
# 128          162             0
# 129          164             0
# 130          165             0
# 131          166             0
# 132          167             0
# 133          168             0
# 309          391             0
# 310          392             0
# 311          393             0
# 312          394             0
# 313          395             0
# 314          396             0
# ...
